# %%
d = {}

# %%
major_requirements = {
    'count': 46,  # Total credits required for the major (9 + 19 + 18 = 46)
    'h1': [],  # No courses without options; all foundational and electives are grouped under h2_x
    'h2_1': {  # Foundational Math Courses (Choose one sequence: 9 credits)
        80: 1,  # Number of options to choose
        1: [  # All available courses in Foundational Math Courses
            'MATH221',
            'MATH217',
            'MATH222'
        ],
        2: [ 
            ('MATH221', 'MATH222'),           # Sequence 1
            ('MATH217', 'MATH222')            # Sequence 2
        ],  # No courses that must be taken together within a group
        3: []
    },
    'h2_2': {  # Foundational Data Science Courses (Choose one sequence: 19-20 credits)
        80: 1,  # Number of options to choose
        1: [  # All available courses in Foundational Data Science Courses
            'STAT240',
            'STAT340',
            'COMPSCI220',
            'COMPSCI300',
            'COMPSCI320',
            'LIS461',
            'ECE/ISYE570'
        ],
        2: [],  # No courses that must be taken together within a group
        3: [  # Mutually exclusive course sequences
            ('COMPSCI220', 'COMPSCI300'),     # Sequence 1
            ('LIS461', 'ECE/ISYE570')         # Sequence 2
        ]
    },
    'h2_3': {  # Electives - Machine Learning (Choose one: 3 credits)
        80: 1,  # Number of options to choose
        1: [  # All available Machine Learning courses
            'COMPSCI/ECE/ME532',
            'COMPSCI/ECE/ME539',
            'COMPSCI540',
            'GENBUS656',
            'ISYE521',
            'MATH535',
            'PHYSICS361',
            'STAT451',
            'STAT453'
        ],
        2: [],  # No courses that must be taken together within a group
        3: [  # Mutually exclusive options (each course is an option)
            ('COMPSCI/ECE/ME532',),
            ('COMPSCI/ECE/ME539',),
            ('COMPSCI540',),
            ('GENBUS656',),
            ('ISYE521',),
            ('MATH535',),
            ('PHYSICS361',),
            ('STAT451',),
            ('STAT453',)
        ]
    },
    'h2_4': {  # Electives - Advanced Computing (Choose one: 3 credits)
        80: 1,  # Number of options to choose
        1: [  # All available Advanced Computing courses
            'COMPSCI400',
            'COMPSCI412',
            'COMPSCI/STAT471',
            'COMPSCI/MATH513',
            'COMPSCI/MATH514',
            'COMPSCI/ECE/ISYE524',
            'COMPSCI544',
            'COMPSCI564',
            'COMPSCI565',
            'COMPSCI/BMI576',
            'GEOG573',
            'GEOG574',
            'MATH444'
        ],
        2: [],  # No courses that must be taken together within a group
        3: [  # Mutually exclusive options (each course is an option)
            ('COMPSCI400',),
            ('COMPSCI412',),
            ('COMPSCI/STAT471',),
            ('COMPSCI/MATH513',),
            ('COMPSCI/MATH514',),
            ('COMPSCI/ECE/ISYE524',),
            ('COMPSCI544',),
            ('COMPSCI564',),
            ('COMPSCI565',),
            ('COMPSCI/BMI576',),
            ('GEOG573',),
            ('GEOG574',),
            ('MATH444',)
        ]
    },
    'h2_5': {  # Electives - Statistical Modeling (Choose one: 3 credits)
        80: 1,  # Number of options to choose
        1: [  # All available Statistical Modeling courses
            'ECON400',
            'ECON410',
            'ECON460',
            'GEOG579',
            'ISYE575',
            'STAT/MATH309',
            'STAT311',
            'MATH/STAT431',
            'STAT/MATH310',
            'STAT312',
            'STAT349',
            'STAT351',
            'STAT421',
            'STAT/ME424',
            'STAT436',
            'STAT443',
            'STAT456',
            'STAT461',
            'STAT575',
            'MATH531',
            'MATH/ISYE/OTM/STAT632',
            'MATH635'
        ],
        2: [],  # No courses that must be taken together within a group
        3: [  # Mutually exclusive options (each course is an option)
            ('ECON400',),
            ('ECON410',),
            ('ECON460',),
            ('GEOG579',),
            ('ISYE575',),
            ('STAT/MATH309',),
            ('STAT311',),
            ('MATH/STAT431',),
            ('STAT/MATH310',),
            ('STAT312',),
            ('STAT349',),
            ('STAT351',),
            ('STAT421',),
            ('STAT/ME424',),
            ('STAT436',),
            ('STAT443',),
            ('STAT456',),
            ('STAT461',),
            ('STAT575',),
            ('MATH531',),
            ('MATH/ISYE/OTM/STAT632',),
            ('MATH635',)
        ]
    },
    'h2_6': {  # Electives - Linear Algebra (Choose one: 3 credits)
        80: 1,  # Number of options to choose
        1: [  # All available Linear Algebra courses
            'MATH320',
            'MATH340',
            'MATH341',
            'MATH375'
        ],
        2: [],  # No courses that must be taken together within a group
        3: [  # Mutually exclusive options (only one course can be chosen)
            ('MATH320',),
            ('MATH340',),
            ('MATH341',),
            ('MATH375',)
        ]
    },
    'h2_7': {  # Electives - Other Electives (Choose multiple to reach 6 credits)
        80: 2,  # Number of options to choose (assuming 2 courses of 3 credits each)
        1: [  # All available Other Elective courses
            'COMPSCI/ISYE/MATH425',
            'COMPSCI/ISYE/MATH/STAT525',
            'COMPSCI/ECE533',
            'COMPSCI559',
            'COMPSCI/BMI567',
            'COMPSCI577',
            'ECE203',
            'ECON315',
            'ECON570',
            'ECON695',
            'GEOG378',
            'GEOG572',
            'GEOG575',
            'ISYE323',
            'ISYE412',
            'ISYE/ME512',
            'ISYE612',
            'INFOSYS322',
            'LIS407',
            'LIS440',
            'LIS464',
            'LIS501',
            'LSC460',
            'LSC660',
            'MATH331',
            'SOC351',
            'SOC/C&E SOC618',
            'SOC/C&E SOC693',
            'SOILSCI585',
            'STAT405',
            'STAT433'
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive constraints within this category
    }
}

# %%
d['data-science-bs'] = major_requirements

# %%
major_requirements = {
    'count': 36,  # Total credits required for the major (36-43)
    'h1': [],      # No standalone required courses
    'h2_1': {      # Mathematics - Selection Step 1 (5-6 credits ≈ 2 classes)
        80: 2,      # Number of classes to choose
        1: [
            'MATH112',  # Option 1: MATH112 & MATH113 (Algebra and Trigonometry)
            'MATH113',
            'MATH114',  # Option 2: MATH114 (Algebra and Trigonometry)
            'MATH171'   # Option 3: MATH171 (Calculus with Algebra and Trigonometry I)
        ],
        2: [
            ('MATH112', 'MATH113')  # Must take both MATH112 and MATH113 if choosing Option 1
        ],
        3: [
            ('MATH112', 'MATH113'),  # Option 1: MATH112 & MATH113 (2 classes)
            ('MATH114',),            # Option 2: MATH114 (1 class)
            ('MATH171',)             # Option 3: MATH171 (1 class)
        ]
    },
    'h2_2': {      # Mathematics - Selection Step 2 (5 credits ≈ 2 classes)
        80: 2,      # Number of classes to choose
        1: [
            'MATH211',   # Option 1: MATH211 (Survey of Calculus 1)
            'MATH217',   # Option 2: MATH217 (Calculus with Algebra and Trigonometry II)
            'MATH221',   # Option 3: MATH221 (Calculus and Analytic Geometry 1)
            'STAT371'    # Option 4: STAT371 (Introductory Applied Statistics for the Life Sciences)
        ],
        2: [
            ('MATH171', 'MATH217')  # Dependency: If MATH171 is taken, MATH217 must be taken
        ],
        3: [
            ('MATH211',),  # Option 1: MATH211 (1 class)
            ('MATH217',),  # Option 2: MATH217 (1 class)
            ('MATH221',),  # Option 3: MATH221 (1 class)
            ('STAT371',)   # Option 4: STAT371 (1 class)
        ]
    },
    'h2_3': {      # Chemistry (Select one option: 5-9 credits ≈ 3 classes)
        80: 3,      # Number of classes to choose
        1: [
            'CHEM103', 'CHEM104',  # Option 1: CHEM103 & CHEM104 (General Chemistry I & II)
            'CHEM109'               # Option 2: CHEM109 (Advanced General Chemistry)
        ],
        2: [
            ('CHEM103', 'CHEM104')  # Must take both CHEM103 and CHEM104 if choosing Option 1
        ],
        3: [
            ('CHEM103', 'CHEM104'),  # Option 1: CHEM103 & CHEM104 (2 classes)
            ('CHEM109',)             # Option 2: CHEM109 (1 class)
        ]
    },
    'h2_4': {      # Biology (Select one of the three options ≈ 4 classes)
        80: 4,      # Number of classes to choose
        1: [
            # Option 1
            'BIOLOGY/BOTANY/ZOOLOGY151',
            'BIOLOGY/BOTANY/ZOOLOGY152',
            # Option 2
            'ZOOLOGY/BIOLOGY101',
            'ZOOLOGY/BIOLOGY102',
            'BOTANY/BIOLOGY130',
            # Option 3
            'BIOCORE381',
            'BIOCORE382',
            'BIOCORE383',
            'BIOCORE384'
        ],
        2: [],
        3: [
            ('BIOLOGY/BOTANY/ZOOLOGY151', 'BIOLOGY/BOTANY/ZOOLOGY152'),  # Option 1: 2 classes
            ('ZOOLOGY/BIOLOGY101', 'ZOOLOGY/BIOLOGY102', 'BOTANY/BIOLOGY130'),  # Option 2: 3 classes
            ('BIOCORE381', 'BIOCORE382', 'BIOCORE383', 'BIOCORE384')  # Option 3: 4 classes
        ]
    },
    'h2_5': {      # Physics (Select one option: 3-5 credits ≈ 2 classes)
        80: 2,      # Number of classes to choose
        1: [
            'PHYSICS103',  # Option 1: PHYSICS103 (General Physics)
            'PHYSICS107',  # Option 2: PHYSICS107 (The Ideas of Modern Physics)
            'PHYSICS109',  # Option 3: PHYSICS109 (Physics in the Arts)
            'PHYSICS115',  # Option 4: PHYSICS115 (Energy and Climate)
            'PHYSICS201',  # Option 5: PHYSICS201 (General Physics)
            'PHYSICS207'   # Option 6: PHYSICS207 (General Physics)
        ],
        2: [],
        3: [
            ('PHYSICS103',),  # Option 1: PHYSICS103 (1 class)
            ('PHYSICS107',),  # Option 2: PHYSICS107 (1 class)
            ('PHYSICS109',),  # Option 3: PHYSICS109 (1 class)
            ('PHYSICS115',),  # Option 4: PHYSICS115 (1 class)
            ('PHYSICS201',),  # Option 5: PHYSICS201 (1 class)
            ('PHYSICS207',)   # Option 6: PHYSICS207 (1 class)
        ]
    },
    'h2_6': {      # Entomology Core (11 credits ≈ 4 classes)
        80: 4,      # Number of classes to choose
        1: [
            # Organismal Subset
            'ENTOM331', 'ENTOM432', 'ENTOM450', 'ENTOM451', 'ENTOM468', 'ENTOM473', 'ENTOM632', 'ENTOM633', 'ENTOM634', 'ENTOM701',
            # Suborganismal Subset
            'ENTOM321', 'ENTOM505', 'ENTOM624',
            # Applied Subset
            'ENTOM350', 'ENTOM351', 'ENTOM371', 'ENTOM500',
            # Other Subset
            'ENTOM375', 'ENTOM399', 'ENTOM681', 'ENTOM682', 'ENTOM691', 'ENTOM699'
        ],
        2: [],
        3: [
            ('ENTOM331', 'ENTOM432', 'ENTOM450', 'ENTOM451', 'ENTOM468', 'ENTOM473', 'ENTOM632', 'ENTOM633', 'ENTOM634', 'ENTOM701'),  # Organismal (10 classes)
            ('ENTOM321', 'ENTOM505', 'ENTOM624'),  # Suborganismal (3 classes)
            ('ENTOM350', 'ENTOM351', 'ENTOM371', 'ENTOM500'),  # Applied (4 classes)
            ('ENTOM375', 'ENTOM399', 'ENTOM681', 'ENTOM682', 'ENTOM691', 'ENTOM699')   # Other (6 classes)
        ]
    },
    'h2_7': {      # Capstone (3 credits ≈ 1 class)
        80: 1,      # Number of classes to choose
        1: [
            'ENTOM468',  # Option 1: Studies in Field Entomology
            'ENTOM681',  # Option 2: Senior Honors Thesis
            'ENTOM682',  # Option 3: Senior Honors Thesis
            'ENTOM691',  # Option 4: Senior Thesis
            'ENTOM699'   # Option 5: Special Problems
        ],
        2: [],
        3: [
            ('ENTOM468',),  # Option 1: ENTOM468 (1 class)
            ('ENTOM681',),  # Option 2: ENTOM681 (1 class)
            ('ENTOM682',),  # Option 3: ENTOM682 (1 class)
            ('ENTOM691',),  # Option 4: ENTOM691 (1 class)
            ('ENTOM699',)   # Option 5: ENTOM699 (1 class)
        ]
    },
    'h2_8': {      # Other Electives (6 credits ≈ 2 classes)
        80: 2,      # Number of classes to choose
        1: [
            'GENETICS466', 'CHEM341', 'CHEM342', 'CHEM343', 'CHEM344', 'CHEM345', 'PHYSICS104',
            'PHYSICS202', 'PHYSICS208', 'ENTOMXXXX', 'BOTANY', 'ZOOLOGY', 'F&W_ECOL', 'MICRO', 'PL_PATH',
            # Suggested courses/subjects include GENETICS 466, CHEM 341-345, PHYSICS 104, 202, 208, ENTOM not used elsewhere, BOTANY, ZOOLOGY, F&W ECOL, MICRO, PL PATH
            # Add more courses as needed based on user requirements
        ],
        2: [],
        3: []       # No mutually exclusive constraints within this category
    }
}

# %%
d['entomology-bs'] = major_requirements

# %%
major_requirements = {
    'count': (14, 20) + (30, 30),  # Total Credits: 14-20 (Math, Chemistry, Physics) + 30 (Biology and Botany)
    'h1': [],      # No standalone required courses
    'h2_1': {      # Statistics/Mathematics (One course from the following): 1 class
        80: 1,      # Number of classes to choose
        1: [
            'STAT301',  # Option 1: Introduction to Statistical Methods
            'STAT324',  # Option 2: Introductory Applied Statistics for Engineers
            'STAT371'   # Option 3: Introductory Applied Statistics for the Life Sciences
        ],
        2: [],
        3: [
            ('STAT301',),  # Option 1: 1 class
            ('STAT324',),  # Option 2: 1 class
            ('STAT371',)   # Option 3: 1 class
        ]
    },
    'h2_2': {      # General Chemistry (One of the following): 5-9 credits ≈ 2-3 classes
        80: 3,      # Number of classes to choose (max approximation)
        1: [
            'CHEM103', 'CHEM104',  # Option 1: General Chemistry I & II
            'CHEM115', 'CHEM116',  # Option 2: Chemical Principles I & II
            'CHEM109',               # Option 3: Advanced General Chemistry
            'CHEM341',               # Option 4: Elementary Organic Chemistry
            'CHEM343'                # Option 5: Organic Chemistry I
        ],
        2: [
            ('CHEM103', 'CHEM104'),  # Must take both CHEM103 and CHEM104 if choosing Option 1
            ('CHEM115', 'CHEM116')   # Must take both CHEM115 and CHEM116 if choosing Option 2
        ],
        3: [
            ('CHEM103', 'CHEM104'),  # Option 1: 2 classes
            ('CHEM115', 'CHEM116'),  # Option 2: 2 classes
            ('CHEM109',),             # Option 3: 1 class
            ('CHEM341',),             # Option 4: 1 class
            ('CHEM343',)              # Option 5: 1 class
        ]
    },
    'h2_3': {      # Organic Chemistry 2 (Choose one): 1 class
        80: 1,      # Number of classes to choose
        1: [
            'CHEM341',  # Option 1: Elementary Organic Chemistry
            'CHEM343'   # Option 2: Organic Chemistry I
        ],
        2: [],
        3: [
            ('CHEM341',),  # Option 1: 1 class
            ('CHEM343',)   # Option 2: 1 class
        ]
    },
    'h2_4': {      # Physics (One course from the following): 1-2 classes
        80: 2,      # Number of classes to choose
        1: [
            'PHYSICS115',  # Option 1: Energy and Climate (preferred)
            'PHYSICS103',  # Option 2: General Physics
            'PHYSICS104',  # Option 3: General Physics
            'PHYSICS201',  # Option 4: General Physics
            'PHYSICS202',  # Option 5: General Physics
            'PHYSICS207',  # Option 6: General Physics
            'PHYSICS208',  # Option 7: General Physics
            'PHYSICS247',  # Option 8: A Modern Introduction to Physics
            'PHYSICS248',  # Option 9: A Modern Introduction to Physics
            'PHYSICS249'   # Option 10: A Modern Introduction to Physics
        ],
        2: [],
        3: [
            ('PHYSICS115',),  # Option 1: 1 class
            ('PHYSICS103',),  # Option 2: 1 class
            ('PHYSICS104',),  # Option 3: 1 class
            ('PHYSICS201',),  # Option 4: 1 class
            ('PHYSICS202',),  # Option 5: 1 class
            ('PHYSICS207',),  # Option 6: 1 class
            ('PHYSICS208',),  # Option 7: 1 class
            ('PHYSICS247',),  # Option 8: 1 class
            ('PHYSICS248',),  # Option 9: 1 class
            ('PHYSICS249',)   # Option 10: 1 class
        ]
    },
    'h2_5': {      # Biology and Botany Requirements (Select one option): 2-4 classes
        80: 4,      # Number of classes to choose
        1: [
            # Option A: BOTANY/BIOLOGY 130 (General Botany)
            'BOTANY130',
            # Option B: Introductory Biology
            'BOTANY151',
            'BOTANY152',
            # Option C: BIOCORE
            'BIOCORE381',
            'BIOCORE382',
            'BIOCORE383',
            'BIOCORE384',
            'BIOCORE485'
        ],
        2: [],
        3: [
            ('BOTANY130',),  # Option A: 1 class
            ('BOTANY151', 'BOTANY152'),  # Option B: 2 classes
            ('BIOCORE381', 'BIOCORE382', 'BIOCORE383', 'BIOCORE384', 'BIOCORE485')  # Option C: 5 classes
        ]
    },
    'h2_6': {      # Botany Distribution - Five courses: 5 classes (since each course is 1 class)
        80: 5,      # Number of classes to choose
        1: [
            # Cell, Molecular, Physiology (1 course required)
            'BOTANY300',  # Plant Anatomy
            'BOTANY500',  # Plant Physiology,
            # Ecology (1 course required)
            'BOTANY455',  # The Vegetation of Wisconsin
            'BOTANY460',  # General Ecology
            # Genetics, Evolution (1 course required)
            'BOTANY410',  # Evolutionary Biology
            'BOTANY338',  # Plant Breeding and Biotechnology
            'GENETICS466',  # Principles of Genetics 2
            'GENETICS467',  # General Genetics 1
            'GENETICS468',  # General Genetics 2
            'BOTANY305',  # Plant Morphology and Evolution
            'BOTANY330',  # Algae
            'BOTANY332',  # Fungi
            'BOTANY400',  # Plant Systematics
            'BOTANY401',  # Vascular Flora of Wisconsin
            # Optional (1 of the 5 required courses may come from the list or take a second course from any area)
            'BOTANY338',  # Environmental Biogeography
            'BOTANY339',  # Plant Biotechnology: Principles and Techniques I
            'BOTANY370',  # Grassland Ecology
            'BOTANY402',  # Dendrology: Woody Plant Identification and Ecology
            'BOTANY403',  # Field Collections and Identification
            'BOTANY422',  # Plant Geography
            'BOTANY450',  # Midwestern Ecological Issues: A Case Study Approach
            'BOTANY473',  # Plant-Insect Interactions
            'BOTANY474',  # Ethnobotany
            'BOTANY505',  # Plant-Microbe Interactions: Molecular and Ecological Aspects
            'BOTANY563',  # Phylogenetic Analysis of Molecular Data
            'BOTANY621',  # Plant Biochemistry
            'BOTANY651',  # Conservation Biology
            'BIOCHEM501',  # Introduction to Biochemistry
            'BIOCORE486',  # Principles of Physiology Laboratory
            'BIOCORE587',  # Biological Interactions
            'FW_ECOL415',   # Tree Physiology
            'MICRO303',     # Biology of Microorganisms
            'ZOOLOGY570',   # Cell Biology
        ],
        2: [],
        3: [
            # Must select at least one from each required subset
            ('BOTANY300', 'BOTANY500'),  # Cell, Molecular, Physiology
            ('BOTANY455', 'BOTANY460'),  # Ecology
            ('BOTANY410', 'BOTANY338', 'GENETICS466', 'GENETICS467', 'GENETICS468'),  # Genetics, Evolution
            ('BOTANY305', 'BOTANY330', 'BOTANY332', 'BOTANY400', 'BOTANY401', 'BOTANY338', 'BOTANY339', 'BOTANY370', 'BOTANY402', 'BOTANY403', 'BOTANY422', 'BOTANY450', 'BOTANY473', 'BOTANY474', 'BOTANY505', 'BOTANY563', 'BOTANY621', 'BOTANY651', 'BIOCHEM501', 'BIOCORE486', 'BIOCORE587', 'FW_ECOL415', 'MICRO303', 'ZOOLOGY570')  # Optional/Other
        ]
    },
    'h2_7': {      # Independent Research Experience—choose one: 6 credits ≈ 2 classes
        80: 2,      # Number of classes to choose
        1: [
            'BOTANY691', 'BOTANY692',  # Option 1: Senior Thesis and Senior Thesis
            'BOTANY681', 'BOTANY682',  # Option 2: Senior Honors Thesis and Senior Honors Thesis
            'BOTANY699'                  # Option 3: Directed Study
        ],
        2: [],
        3: [
            ('BOTANY691', 'BOTANY692'),  # Option 1: 2 classes
            ('BOTANY681', 'BOTANY682'),  # Option 2: 2 classes
            ('BOTANY699',)               # Option 3: 1 class
        ]
    },
    'h2_8': {      # Other Electives (Approx 2 classes)
        80: 2,      # Number of classes to choose
        1: [
            'GENETICS466', 'CHEM341', 'CHEM342', 'CHEM343', 'CHEM344', 'CHEM345', 'PHYSICS104',
            'PHYSICS202', 'PHYSICS208', 'ENTOMXXXX', 'BOTANY', 'ZOOLOGY', 'FW_ECOL', 'MICRO', 'PL_PATH',
            # Additional electives can be added here
        ],
        2: [],
        3: []       # No mutually exclusive constraints within this category
    }
}

# %%
# d['botany-bs'] = major_requirements

# %%
major_requirements = {
    'count': 12,  # Total credits required for the certificate
    'h1': [  # List of core accounting and finance courses
        'ACCTI_S100 — Introductory Financial Accounting',
        'ACCTI_S211 — Introductory Managerial Accounting',
        'ACCTI_S301 — Financial Reporting I',
        'FINANCE/ECON300 — Introduction to Finance'
    ]
}

# %%
d['accounting-fundamentals-certificate'] = major_requirements

# %%
major_requirements = {
    'count': 30,  # Total credits required for the major
    'h2_1': {  # Literature (Choose two courses)
        80: 2,  # Number of courses to choose
        1: [  # All available Literature courses
            'AFROAMER222',  # Introduction to Black Women Writers
            'AFROAMER225',  # Introduction to African American Dramatic Literature
            'AFROAMER227',  # Masterpieces of African American Literature
            'AFROAMER265',  # African-American Autobiography
            'AFROAMER337',  # The Harlem Renaissance
            'AFROAMER338'   # The Black Arts Movement
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },
    'h2_2': {  # History and Society (Choose two courses)
        80: 2,
        1: [  # All available History and Society courses
            'AFROAMER151',  # Introduction to Contemporary Afro-American Society
            'AFROAMER231',  # Introduction to Afro-American History
            'AFROAMER272',  # Race and American Politics from the New Deal to the New Right
            'AFROAMER321',  # Afro-American History Since 1900
            'AFROAMER322',  # Afro-American History to 1900
            'AFROAMER324',  # Black Women in America: Reconstruction to the Present
            'AFROAMER326',  # Race and Gender in Post-World War II U.S. Society
            'AFROAMER393'   # Slavery, Civil War, and Reconstruction, 1848-1877
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },
    'h2_3': {  # Arts and Culture (Choose two courses)
        80: 2,
        1: [  # All available Arts and Culture courses
            'AFROAMER154',  # Hip-Hop and Contemporary American Society
            'AFROAMER156',  # Black Music and American Cultural History
            'AFROAMER241',  # Introduction to African Art and Architecture
            'AFROAMER242',  # Introduction to Afro-American Art
            'AFROAMER267',  # Artistic/Cultural Images of Black Women
            'AFROAMER303',  # Blacks, Film, and Society
            'AFROAMER367'   # Art and Visual Culture: Women of the African Diaspora and Africa
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },
    'h2_4': {  # Seminars and Advanced Courses (Choose two courses)
        80: 2,
        1: [  # All available Seminars and Advanced Courses
            'AFROAMER624',  # African American Women's Activism (19th & 20th Centuries)
            'AFROAMER625',  # Gender, Race and the Civil Rights Movement
            'AFROAMER628',  # History of the Civil Rights Movement in the United States
            'AFROAMER631',  # Colloquium in Afro-American History
            'AFROAMER669',  # Interdisciplinary Studies in the Arts
            'AFROAMER671',  # Selected Topics in Afro-American History
            'AFROAMER672',  # Selected Topics in Afro-American Literature
            'AFROAMER673',  # Selected Topics in Afro-American Society
            'AFROAMER675',  # Selected Topics in Afro-American Culture
            'AFROAMER677',  # Critical and Theoretical Perspectives in Black Women's Writings
            'AFROAMER679'   # Visual Culture, Gender and Critical Race Theory
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },
    'h2_5': {  # Electives (Choose two courses)
        80: 2,
        1: [  # All available Elective courses
            'AFROAMER102',  # Introduction to Comparative US Ethnic and American Indian Studies
            'AFROAMER155',  # They: Race in American Literature
            'AFROAMER221',  # Introduction to Black Women's Studies
            'AFROAMER271',  # Selected Topics in African American Culture
            'AFROAMER297',  # African and African-American Linkages: An Introduction
            'AFROAMER302',  # Undergraduate Studies in Afro-American History
            'AFROAMER318',  # Cultural Cross Currents: West African Dance/Music in the Americas
            'AFROAMER323',  # Gender, Race and Class: Women in U.S. History
            'AFROAMER333',  # Black Feminisms
            'AFROAMER347',  # The Caribbean and its Diasporas
            'AFROAMER456',  # Soul Music and the African American Freedom Movement
            'AFROAMER469',  # Interdisciplinary Studies in the Arts
            'AFROAMER519',  # African American Political Theory
            'AFROAMER523',  # Race, American Medicine and Public Health
            'AFROAMER567'   # History of African American Education
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    }
}

# %%
d['african-american-studies-ba'] = major_requirements

# %%
major_requirements = {
    'count': 30,  # Total credits required for the major

    'h2_1': {  # Literature (Choose two courses)
        80: 2,  # Number of courses to choose
        1: [  # All available Literature courses
            'AFROAMER222',  # Introduction to Black Women Writers
            'AFROAMER225',  # Introduction to African American Dramatic Literature
            'AFROAMER227',  # Masterpieces of African American Literature
            'AFROAMER265',  # African-American Autobiography
            'AFROAMER337',  # The Harlem Renaissance
            'AFROAMER338'   # The Black Arts Movement
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },

    'h2_2': {  # History and Society (Choose two courses)
        80: 2,
        1: [  # All available History and Society courses
            'AFROAMER151',  # Introduction to Contemporary Afro-American Society
            'AFROAMER231',  # Introduction to Afro-American History
            'AFROAMER272',  # Race and American Politics from the New Deal to the New Right
            'AFROAMER321',  # Afro-American History Since 1900
            'AFROAMER322',  # Afro-American History to 1900
            'AFROAMER324',  # Black Women in America: Reconstruction to the Present
            'AFROAMER326',  # Race and Gender in Post-World War II U.S. Society
            'AFROAMER393'   # Slavery, Civil War, and Reconstruction, 1848-1877
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },

    'h2_3': {  # Arts and Culture (Choose two courses)
        80: 2,
        1: [  # All available Arts and Culture courses
            'AFROAMER154',  # Hip-Hop and Contemporary American Society
            'AFROAMER156',  # Black Music and American Cultural History
            'AFROAMER241',  # Introduction to African Art and Architecture
            'AFROAMER242',  # Introduction to Afro-American Art
            'AFROAMER267',  # Artistic/Cultural Images of Black Women
            'AFROAMER303',  # Blacks, Film, and Society
            'AFROAMER367'   # Art and Visual Culture: Women of the African Diaspora and Africa
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },

    'h2_4': {  # Seminars and Advanced Courses (Choose two courses)
        80: 2,
        1: [  # All available Seminars and Advanced Courses
            'AFROAMER624',  # African American Women's Activism (19th & 20th Centuries)
            'AFROAMER625',  # Gender, Race and the Civil Rights Movement
            'AFROAMER628',  # History of the Civil Rights Movement in the United States
            'AFROAMER631',  # Colloquium in Afro-American History
            'AFROAMER669',  # Interdisciplinary Studies in the Arts
            'AFROAMER671',  # Selected Topics in Afro-American History
            'AFROAMER672',  # Selected Topics in Afro-American Literature
            'AFROAMER673',  # Selected Topics in Afro-American Society
            'AFROAMER675',  # Selected Topics in Afro-American Culture
            'AFROAMER677',  # Critical and Theoretical Perspectives in Black Women's Writings
            'AFROAMER679'   # Visual Culture, Gender and Critical Race Theory
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    },

    'h2_5': {  # Electives (Choose two courses)
        80: 2,
        1: [  # All available Elective courses
            'AFROAMER102',  # Introduction to Comparative US Ethnic and American Indian Studies
            'AFROAMER155',  # They: Race in American Literature
            'AFROAMER221',  # Introduction to Black Women's Studies
            'AFROAMER271',  # Selected Topics in African American Culture
            'AFROAMER297',  # African and African-American Linkages: An Introduction
            'AFROAMER302',  # Undergraduate Studies in Afro-American History
            'AFROAMER318',  # Cultural Cross Currents: West African Dance/Music in the Americas
            'AFROAMER323',  # Gender, Race and Class: Women in U.S. History
            'AFROAMER333',  # Black Feminisms
            'AFROAMER347',  # The Caribbean and its Diasporas
            'AFROAMER456',  # Soul Music and the African American Freedom Movement
            'AFROAMER469',  # Interdisciplinary Studies in the Arts
            'AFROAMER519',  # African American Political Theory
            'AFROAMER523',  # Race, American Medicine and Public Health
            'AFROAMER567'   # History of African American Education
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings
    }
}

# %%
d['african-american-studies-bs'] = major_requirements

# %%
major_requirements = {
    'count': 65,  # Minimum total credits required for the major

    'h2_1': {  # Mathematics and Statistics
        80: 2,  # Number of course options to choose
        1: [  # All available Mathematics and Statistics courses
            'MATH221',  # Calculus and Analytic Geometry 1
            'MATH171',  # Calculus with Algebra and Trigonometry I
            'MATH217',  # Calculus with Algebra and Trigonometry II
            'STAT371',  # Introductory Applied Statistics for the Life Sciences
            'STAT301',  # Introduction to Statistical Methods
            'STAT240'   # Data Science Modeling I
        ],
        2: [  # Courses that must be taken together
            ('MATH171', 'MATH217')  # If MATH171 is taken, MATH217 must also be taken
        ],
        3: [  # Mutually exclusive course sequences
            ('MATH221',),
            ('MATH171', 'MATH217'),
            ('STAT371',),
            ('STAT301',),
            ('STAT240',)
        ]
    },

    'h2_2': {  # Chemistry
        80: 1,  # Number of course options to choose
        1: [  # All available Chemistry courses
            'CHEM103', 'CHEM104',  # General Chemistry I and II
            'CHEM109',               # Advanced General Chemistry
            'CHEM115', 'CHEM116',    # Chemical Principles I and II
            'CHEM341',               # Elementary Organic Chemistry
            'CHEM343', 'CHEM345'     # Organic Chemistry I and II
        ],
        2: [  # Courses that must be taken together
            ('CHEM103', 'CHEM104'),  # General Chemistry I and II
            ('CHEM115', 'CHEM116'),  # Chemical Principles I and II
            ('CHEM343', 'CHEM345')   # Organic Chemistry I and II
        ],
        3: [  # Mutually exclusive course sequences
            ('CHEM103', 'CHEM104'),
            ('CHEM115', 'CHEM116'),
            ('CHEM109',),
            ('CHEM341',),
            ('CHEM343', 'CHEM345')
        ]
    },

    'h2_3': {  # Physics
        80: 1,  # Number of course options to choose
        1: [  # All available Physics courses
            'PHYSICS103', 'PHYSICS104',  # General Physics (recommended)
            'PHYSICS201', 'PHYSICS202',  # General Physics
            'PHYSICS207', 'PHYSICS208',  # General Physics (recommended)
            'PHYSICS566',                # Advanced Physics
            'PHYSICS567'                 # Companion Research Seminar (must be taken concurrently with certain options)
        ],
        2: [],  # No courses that must be taken together within a group
        3: []   # No mutually exclusive course groupings beyond choosing one option
    },

    'h2_4': {  # Biology
        80: 1,  # Number of option sets to choose
        1: [  # All available Biology options
            # Option 1
            'BIOLOGY151', 'BIOLOGY152',  # Introductory Biology and Introductory Biology (recommended)
            # Option 2
            'BOTANY130',
            'ZOOLOGY101', 'ZOOLOGY102',  # Animal Biology and Animal Biology Laboratory
             #Option 3
            'BIOCORE381', 'BIOCORE383',  # Evolution, Ecology, and Genetics and Cellular Biology
            # Select two lab
            'BIOCORE382',
            'BIOCORE384',
            'BIOCORE486',
        ],
        2: [  # Courses that must be taken together
            ('BIOLOGY151', 'BIOLOGY152'),
            ('ZOOLOGY101', 'ZOOLOGY102'),
            ('BIOCORE381', 'BIOCORE383')
        ],
        3: [  # Mutually exclusive option sets
            ('BIOLOGY151', 'BIOLOGY152'),  # Option 1
            ('BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102'),  # Option 2
            ('BIOCORE381', 'BIOCORE383', 'BIOCORE382', 'BIOCORE384', 'BIOCORE486')  # Option 3 and labs
        ]
    },

    'h2_5': {  # Core Requirements
        80: 1,  # Number of option sets to choose
        1: [  # All available Core Requirements options
            # Option 1
            'BIOCHEM501',  # Introduction to Biochemistry 2
            # Option 2
            'BIOCHEM507', 'BIOCHEM508',  # General Biochemistry I and II
            # Option 3
            'GENETICS467', 'GENETICS468',  # General Genetics 1 and 2 (preferred)
            # Option 4
            'GENETICS466', 'GENETICSDepthCourse',  # Principles of Genetics (consult advisor) and additional genetics depth course
            # Additional options can be added as needed
        ],
        2: [  # Courses that must be taken together
            ('BIOCHEM507', 'BIOCHEM508'),
            ('GENETICS467', 'GENETICS468')
        ],
        3: [  # Mutually exclusive course sequences
            ('BIOCHEM501',),
            ('BIOCHEM507', 'BIOCHEM508'),
            ('GENETICS467', 'GENETICS468'),
            ('GENETICS466',)  # Assuming 'GENETICSDepthCourse' is handled separately
        ]
    },

    'h2_6': {  # Genetics Depth & Breadth
        80: 2,  # Number of categories to choose (Depth and Breadth)
        1: [  # All available Genetics Depth and Breadth courses
            # Genetics Depth Courses
            'GENETICS520',  # Neurogenetics
            'GENETICS522',  # Communicating Evolutionary Biology
            'GENETICS525',  # Epigenetics
            'GENETICS527',  # Developmental Genetics for Conservation and Regeneration
            'GENETICS528',  # Banking Animal Biodiversity: International Field Study in Costa Rica
            'GENETICS548',  # The Genomic Revolution
            'GENETICS550',  # Molecular Approaches for Potential Crop Improvement
            'GENETICS564',  # Genomics and Proteomics
            'GENETICS565',  # Human Genetics
            'GENETICS566',  # Advanced Genetics
            'GENETICS588',  # Immunogenetics
            'GENETICS605',  # Clinical Cases in Medical Genetics
            'GENETICS612',  # Prokaryotic Molecular Biology
            'GENETICS620',  # Eukaryotic Molecular Biology
            'GENETICS626',  # Genomic Science
            'GENETICS627',  # Animal Developmental Genetics
            'GENETICS631',  # Plant Genetics and Development
            'GENETICS633',  # Population Genetics
            'GENETICS655',  # Biology and Genetics of Fungi
            'GENETICS662',  # Cancer Genetics
            'GENETICS677',  # Advanced Topics in Genetics
            # Genetics Breadth Courses
            'BIOCHEM508',  # General Biochemistry II
            'BIOCHEM560',  # Principles of Human Disease and Biotechnology
            'CHEM344',      # Introductory Organic Chemistry Laboratory
            'CHEM345',      # Organic Chemistry II
            'BIOCHEM575',   # Biology of Viruses
            'BIOCORE485',   # Principles of Physiology
            'BIOCORE587',   # Biological Interactions
            'BOTANY410',    # Evolutionary Biology
            'BOTANY563',    # Phylogenetic Analysis of Molecular Data
            'MICROBIO303',  # Biology of Microorganisms
            'MICROBIO304',  # Biology of Microorganisms Laboratory
            'MICROBIO470',  # Microbial Genetics & Molecular Machines
            'MICROBIO545',  # Topics in Biotechnology
            'MICROBIO632',  # Industrial Microbiology/Biotechnology
            'MM&I341',      # Immunology
            'MM&I528',      # Immunology
            'PHMSCI490',    # Selected Topics in Pharmaceutical Sciences
            'PLPATH622',    # Plant-Bacterial Interactions
            'PLPATH640',    # General Virology-Multiplication of Viruses
            'ZOOLOGY360',   # Extinction of Species
            'ZOOLOGY425',   # Behavioral Ecology
            'ZOOLOGY470',   # Introduction to Animal Development
            'ZOOLOGY555',   # Laboratory in Developmental Biology
            'ZOOLOGY570',   # Cell Biology
            'AGRONOMY338',  # Plant Breeding and Biotechnology
            'AGRONOMY340',  # Plant Cell Culture and Genetic Engineering
            'AGRONOMY360',  # Genetically Modified Crops: Science, Regulation & Controversy
            'AGRONOMY501',  # Principles of Plant Breeding
            'AGRONOMY502',  # Techniques of Plant Breeding
            'ANSCI361',     # Introduction to Animal and Veterinary Genetics
            'ANSCI362',     # Veterinary Genetics
            'ANSCI363',     # Principles of Animal Breeding
            'PLPATH505',    # Plant-Microbe Interactions: Molecular and Ecological Aspects
            'BMICOMP576',   # Introduction to Bioinformatics
            'BIOCHEM570'    # (Assuming it's an additional Genetics Depth course)
        ],
        2: [  # Courses that must be taken together within a group
            # No explicit groupings, handled via selection of Depth and Breadth separately
        ],
        3: [  # Mutually exclusive groupings
            # Not applicable as Depth and Breadth are separate categories
        ]
    },

    'h2_7': {  # Capstone
        80: 1,  # Number of course options to choose
        1: [  # All available Capstone options
            'GENETICS522',  # Communicating Evolutionary Biology
            'GENETICS527', # Developmental Genetics for Conservation and Regeneration
            'GENETICS566',  # Advanced Genetics
            'GENETICS564',  # Genomics and Proteomics
            'GENETICS699', 'GENETICS567'  # Special Problems & Companion Research Seminar (must be taken concurrently)
            'GENETICS681', 'GENETICS682', 'GENETICS567' # Senior Honors Thesis & Companion Research Seminar (must be taken concurrently)
        ],
        2: [  # Courses that must be taken together
            ('GENETICS699', 'GENETICS567'),
            ('GENETICS681', 'GENETICS682', 'GENETICS567')
        ],
        3: [  # Mutually exclusive course sequences
            ('GENETICS522',),
            ('GENETICS527',),
            ('GENETICS566',),
            ('GENETICS564',),
            ('GENETICS699', 'GENETICS567'),
            ('GENETICS681', 'GENETICS682', 'GENETICS567')
        ]
    }
}

# %%
d['genetics-and-genomics-bs'] = major_requirements

# %%
major_requirements = {
    'count': 41,  # Minimum total credits required for the major

    'h2_1': {  # Mathematics and Statistics
        80: 2,  # Number of course options to choose
        1: [  # All available Mathematics and Statistics courses
            'MATH213',  # Survey of Calculus 2
            'MATH217',  # Calculus with Algebra and Trigonometry II
            'MATH221',  # Calculus and Analytic Geometry 1
            'ECON205'   # Quantitative Tools for Economics
        ],
        2: [  # Courses that must be taken together
            # No mandatory pairs specified for this category
        ],
        3: [  # Mutually exclusive course sequences
            ('MATH213',),
            ('MATH217',),
            ('MATH221',),
            ('ECON205',)
        ]
    },

    'h2_2': {  # Statistics Courses
        80: 1,  # Number of course options to choose
        1: [  # All available Statistics courses
            'ECON310',    # Statistics: Measurement in Economics
            'STAT301',    # Introduction to Statistical Methods
            'STAT324',    # [Title Not Specified]
            'STAT371',    # Introductory Applied Statistics for the Life Sciences
            'PSYCH210',   # Basic Statistics for Psychology
            'SOC360',     # Statistics for Sociologists I
            'GENBUS306',  # Business Analytics I
            'GENBUS307'   # Business Analytics II
        ],
        2: [  # Courses that must be taken together
            ('GENBUS306', 'GENBUS307')  # Business Analytics I and II must be taken together
        ],
        3: [  # Mutually exclusive course sequences
            ('ECON310',),
            ('STAT301',),
            ('STAT324',),
            ('STAT371',),
            ('PSYCH210',),
            ('SOC360',),
            ('GENBUS306', 'GENBUS307')
        ]
    },

    'h2_3': {  # Core Requirements
        80: 1,  # Number of course options to choose
        1: [  # All available Core Requirements options
            'AAE101',                   # Introduction to Agricultural and Applied Economics
            'ECON101', 'ECON102',       # Principles of Microeconomics and Principles of Macroeconomics
            'ECON301', 'ECON302',       # Intermediate Microeconomic Theory and Intermediate Macroeconomic Theory
            'ECON311', 'ECON312'         # Intermediate Microeconomic Theory - Advanced Treatment and Intermediate Macroeconomic Theory - Advanced Treatment
        ],
        2: [  # Courses that must be taken together
            ('ECON101', 'ECON102'),        # Principles of Micro and Macroeconomics
            ('ECON301', 'ECON302'),        # Intermediate Micro and Macroeconomic Theory
            ('ECON311', 'ECON312')         # Intermediate Advanced Micro and Macro Theories
        ],
        3: [  # Mutually exclusive course sequences
            ('AAE101',),
            ('ECON101', 'ECON102'),
            ('ECON301', 'ECON302'),
            ('ECON311', 'ECON312')
        ]
    },

    'h2_4': {  # Focus Areas within the Major
        80: 1,  # Number of course options to choose (select courses from one focus area)
        1: [  # All available Focus Area courses
            # Applied Economics
            'AAE319', 'AAE350', 'AAE373', 'AAE374', 'AAE462', 'AAE473', 'AAE474', 'AAE477',
            # Development Economics
            'AAE319', 'AAE350', 'AAE373', 'AAE374', 'AAE462', 'AAE473', 'AAE474', 'AAE477',
            # Environmental Economics
            'AAE244', 'AAE246', 'AAE343', 'AAE352', 'AAE371', 'AAE531', 'AAE671',
            # Managerial Economics
            'AAE320', 'AAE322', 'AAE323', 'AAE335', 'AAE419', 'AAE421'
        ],
        2: [  # Courses that must be taken together
            # No specific pairs; selection is based on focus area
        ],
        3: [  # Mutually exclusive course sequences (focus areas are exclusive)
            ('AAE319', 'AAE350', 'AAE373', 'AAE374', 'AAE462', 'AAE473', 'AAE474', 'AAE477'),  # Applied Economics
            ('AAE244', 'AAE246', 'AAE343', 'AAE352', 'AAE371', 'AAE531', 'AAE671'),             # Environmental Economics
            ('AAE320', 'AAE322', 'AAE323', 'AAE335', 'AAE419', 'AAE421')                        # Managerial Economics
        ]
    },

    'h2_5': {  # Capstone
        80: 1,  # Number of course options to choose
        1: [  # All available Capstone options
            'AAE500', # Senior Capstone Experience
        ],
        2: [  # Courses that must be taken together
            # None; single course
        ],
        3: [  # Mutually exclusive course sequences
            ('AAE500',)
        ]
    }
}

# %%
# d['agricultural-and-applied-economics-bs'] = major_requirements

# %%
major_requirements = {
    'count': 71,  # Minimum total credits required for the major

    'h2_1': {  # Mathematics and Statistics
        80: 1,  # Number of course options to choose
        1: [
            'MATH112', 'MATH113',  # Algebra and Trigonometry I & II, 6 credits
            'MATH114',                # Algebra and Trigonometry, 5 credits
            'MATH171',                # Calculus with Algebra and Trigonometry I, 5 credits
            'MATH211',                # Survey of Calculus 1, 5 credits
            'MATH221'                 # Calculus and Analytic Geometry 1, 5 credits
        ],
        2: [
            ('MATH112', 'MATH113')  # Must take together
        ],
        3: [
            ('MATH112', 'MATH113'),  # Mutually exclusive sequences
            ('MATH114',),
            ('MATH171',),
            ('MATH211',),
            ('MATH221',)
        ]
    },

    'h2_2': {  # Statistics
        80: 1,  # Number of course options to choose
        1: [
            'STAT301',      # Introduction to Statistical Methods, 3 credits
            'STAT371',      # Introductory Applied Statistics for the Life Sciences, 3 credits
            'STAT/BMI541',  # Introduction to Biostatistics, 3 credits
            'STAT/F&W ECOL571'  # Statistical Methods for Bioscience I, 3 credits
        ],
        2: [],
        3: [
            ('STAT301',),
            ('STAT371',),
            ('STAT/BMI541',),
            ('STAT/F&W ECOL571',)
        ]
    },

    'h2_3': {  # Chemistry
        80: 1,  # Number of course options to choose
        1: [
            'CHEM103', 'CHEM104',  # General Chemistry I & II, 9 credits
            'CHEM109'                 # Advanced General Chemistry, 5 credits
        ],
        2: [
            ('CHEM103', 'CHEM104')  # Must take together
        ],
        3: [
            ('CHEM103', 'CHEM104'),
            ('CHEM109',)
        ]
    },

    'h2_4': {  # Biology
        80: 3,  # Number of course options to choose (complete one of the following options: 10)
        1: [
            # Option 1
            'BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102',  # General Botany, Animal Biology, Animal Biology Laboratory, total 10 credits
            # Option 2
            'BIOLOGY151', 'ZOOLOGY152',               # Introductory Biology and Introductory Biology, total 10 credits
            # Option 3
            'BIOCORE381', 'BIOCORE382', 'BIOCORE383', 'BIOCORE384'  # Evolution, Ecology, and Genetics & Lab, Cellular Biology & Lab, total 12 credits
        ],
        2: [
            ('BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102'),  # Option 1
            ('BIOLOGY151', 'ZOOLOGY152'),               # Option 2
            ('BIOCORE381', 'BIOCORE382', 'BIOCORE383', 'BIOCORE384')  # Option 3
        ],
        3: [
            ('BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102'),  # Option1
            ('BIOLOGY151', 'ZOOLOGY152'),               # Option2
            ('BIOCORE381', 'BIOCORE382', 'BIOCORE383', 'BIOCORE384')  # Option3
        ]
    },

    'h2_5': {  # Economics
        80: 1,  # Number of course options to choose
        1: [
            'AAE101',    # Introduction to Agricultural and Applied Economics, 4 credits
            'ECON101',   # Principles of Microeconomics, 3 credits
            'ECON111'    # Principles of Economics-Accelerated Treatment, 4 credits
        ],
        2: [],
        3: [
            ('AAE101',),
            ('ECON101',),
            ('ECON111',)
        ]
    },

    'h2_6': {  # Foundation Credits
        80: 1,  # Number of course options to choose (complete 8 credits from any Foundation category)
        1: [
            # Ag Social Science
            'AAE319', 'AAE320', 'AAE322', 'AAE323', 'AAE421', 'AAE474',
            'C&E SOC/SOC140', 'C&E SOC/SOC222', 'C&E SOC/AMER IND/SOC578', 'C&E SOC/SOC650',
            # Animal Science
            'AN SCI/DY SCI101', 'AN SCI200', 'AN SCI/DY SCI/NUTR SCI311',
            'AN SCI431', 'AN SCI432', 'DY SCI205', 'DY SCI/AN SCI361',
            'DY SCI/AN SCI363', 'DY SCI/AN SCI370', 'DY SCI378',
            'ENTOM/ZOOLOGY302', 'ENTOM351',
            # Atmospheric Science
            'ATM OCN100', 'ATM OCN/ENVIR ST171',
            # Biological Systems Engineering
            'BSE301',
            # Food Science
            'FOOD SCI120', 'FOOD SCI440', 'AAE/C&E SOC/SOC340', 'NUTR SCI/BIOCHEM510',
            # Management
            'ACCT IS211', 'ACCT IS301', 'ACCT IS302', 'ACCT IS401',
            'AAE320', 'AAE322', 'AAE323', 'AAE419', 'AAE/ECON421',
            'AAE/ECON474', 'GEN BUS301', 'FINANCE/ECON300',
            'INTL BUS200', 'MARKETING305', 'MARKETING310',
            'MARKETING/INTL BUS420', 'MARKETING424', 'MARKETING426',
            'MARKETING460', 'MHR322', 'MHR420', 'MHR612', 'RMI300',
            # Nutritional Science
            'NUTR SCI132', 'NUTR SCI/AN SCI/DY SCI311',
            'NUTR SCI332', 'NUTR SCI/AAE/AGRONOMY350',
            # Soil Science
            'SOIL SCI/ENVIR ST324',
            # Bacteriology, Biochemistry, Genetics
            'MICROBIO101', 'MICROBIO102', 'MICROBIO303', 'MICROBIO304',
            'MICROBIO/FOOD SCI324', 'MICROBIO/FOOD SCI325',
            'BIOCHEM501', 'GENETICS466',
            # Ecological Sciences
            'F&W ECOL/ENVIR ST100', 'F&W ECOL318', 'F&W ECOL/BOTANY455',
            'F&W ECOL/BOTANY/ZOOLOGY460', 'F&W ECOL550'
        ],
        2: [],
        3: []
    },

    'h2_7': {  # Core
        80: 1,  # Number of course options to choose (complete all of the following: 12)
        1: [
            'AGRONOMY100',                              # Principles and Practices in Crop Production, 3 credits
            'SOIL SCI301', 'SOIL SCI302',             # General Soil Science and Meet Your Soil Lab, 6 credits
            'PL PATH300'                                 # Introduction to Plant Pathology, 3 credits
        ],
        2: [
            ('SOIL SCI301', 'SOIL SCI302')  # Must take together
        ],
        3: [
            ('AGRONOMY100',),
            ('SOIL SCI301', 'SOIL SCI302'),
            ('PL PATH300',)
        ]
    },

    'h2_8': {  # Genetics
        80: 1,  # Number of course options to choose (complete one of the following: 3)
        1: [
            'GENETICS466',            # Principles of Genetics, 3 credits
            'AGRONOMY/HORT338'        # Plant Breeding and Biotechnology, 3 credits
        ],
        2: [],
        3: [
            ('GENETICS466',),
            ('AGRONOMY/HORT338',)
        ]
    },

    'h2_9': {  # Entomology
        80: 1,  # Number of course options to choose (complete one of the following: 3-4)
        1: [
            'ENTOM/ZOOLOGY302',        # Introduction to Entomology, 4 credits
            'ENTOM351'                 # Principles of Economic Entomology, 3 credits
        ],
        2: [],
        3: [
            ('ENTOM/ZOOLOGY302',),
            ('ENTOM351',)
        ]
    },

    'h2_10': {  # Ecology and Land
        80: 1,  # Number of course options to choose (complete one of the following: 3-4)
        1: [
            'AGRONOMY/BOTANY/SOIL SCI370',  # Grassland Ecology, 3 credits
            'BOTANY/F&W ECOL455',           # The Vegetation of Wisconsin, 4 credits
            'BOTANY/F&W ECOL/ZOOLOGY460',   # General Ecology, 4 credits
            'ENVIR ST/LAND ARC361'           # Wetlands Ecology, 3 credits
        ],
        2: [],
        3: [
            ('AGRONOMY/BOTANY/SOIL SCI370',),
            ('BOTANY/F&W ECOL455',),
            ('BOTANY/F&W ECOL/ZOOLOGY460',),
            ('ENVIR ST/LAND ARC361',)
        ]
    },

    'h2_11': {  # Electives within the Major
        80: 1,  # Number of course options to choose (complete 14 additional credits of Agronomy courses)
        1: [
            # List of specific Agronomy courses can be added here
            # Example placeholders:
            'AGRONOMY201', 'AGRONOMY202', 'AGRONOMY203', 'AGRONOMY204',
            'AGRONOMY205', 'AGRONOMY206', 'AGRONOMY207', 'AGRONOMY208',
            'AGRONOMY209', 'AGRONOMY210', 'AGRONOMY211', 'AGRONOMY212',
            'AGRONOMY213', 'AGRONOMY214'
        ],
        2: [],
        3: []
    },

    'h2_12': {  # Capstone
        80: 1,  # Number of course options to choose
        1: [
            'AGRONOMY500'  # Senior Capstone Experience, 2 credits
        ],
        2: [],
        3: [
            ('AGRONOMY500',)
        ]
    }
}

# %%
d['agronomy-bs'] = major_requirements

# %%
major_requirements = {
    'count': (64, 70),  # Total credits required for the major

    'h2_1': {  # Foundational Mathematics
        80: 2,  # Number of course options to choose
        1: [
            'MATH221', 'MATH222',  # Complete both Single Variable Calculus courses
            'MATH234',                # Complete Multivariable Calculus option 1
            'MATH375', 'MATH376'   # Complete Multivariable Calculus option 2
        ],
        2: [
            'MATH221', 'MATH222',
            'MATH375', 'MATH376'
        ],
        3: [
            'MATH221', 'MATH222',
            'MATH234',
            'MATH375', 'MATH376'
        ]
    },

    'h2_2': {  # Foundational Physics
        80: 3,  # Number of course options to choose
        1: [
            'PHYSICS247', 'PHYSICS207', 'PHYSICS201', 'EMA202', 'ME240',  # First Introductory Course options
            'PHYSICS248', 'PHYSICS208', 'PHYSICS202',                      # Second Introductory Course options
            'PHYSICS249', 'PHYSICS241', 'PHYSICS205', 'PHYSICS/ECE235'       # Third Introductory Course options
        ],
        2: [],  # No courses must be taken together within Foundational Physics
        3: [
            ('PHYSICS247',), ('PHYSICS207',), ('PHYSICS201',),
            ('EMA202',), ('ME240',), ('PHYSICS248',),
            ('PHYSICS208',), ('PHYSICS202',), ('PHYSICS249',),
            ('PHYSICS241',), ('PHYSICS205',), ('PHYSICS/ECE235',)
        ]
    },

    'h2_3': {  # Chemistry
        80: 1,  # Number of course options to choose
        1: [
            'CHEM109',           # Advanced General Chemistry
            'CHEM103', 'CHEM104', # General Chemistry I & II
            'CHEM115',            # Chemical Principles I
        ],
        2: [
            ('CHEM103', 'CHEM104')  # Must take General Chemistry I & II together
        ],
        3: [
            ('CHEM109',),
            ('CHEM103', 'CHEM104'),
            ('CHEM115',)
        ]
    },

    'h2_4': {  # Biology
        80: 2,  # Number of course options to choose
        1: [
            'BIOLOGY151', 'BIOLOGY152',          # Option 1: Introductory Biology courses
            'BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102'  # Option 2: General Botany and Animal Biology courses
        ],
        2: [
            ('BIOLOGY151', 'BIOLOGY152'),
            ('BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102')
        ],
        3: [
            ('BIOLOGY151', 'BIOLOGY152'),
            ('BOTANY130', 'ZOOLOGY101', 'ZOOLOGY102')
        ]
    },

    'h2_5': {  # Social Science
        80: 1,  # Number of course options to choose
        1: [
            'C&E SOC/SOC140', 'AAE101'  # Must complete both courses together
        ],
        2: [
            ('C&E SOC/SOC140', 'AAE101')
        ],
        3: [
            ('C&E SOC/SOC140', 'AAE101')
        ]
    },

    'h2_6': {  # Major Core
        80: 1,  # Number of course options to choose
        1: [
            'AGROECOL103', 'AGROECOL303'  # Complete both Agroecology core courses
        ],
        2: [
            ('AGROECOL103', 'AGROECOL303')
        ],
        3: [
            ('AGROECOL103', 'AGROECOL303')
        ]
    },

    'h2_7': {  # Major Breadth
        80: 4,  # Number of course options to choose (one from each thematic area)
        1: [
            # Organisms Thematic Area
            'ENTOM/ZOOLOGY302', 'BOTANY500', 'F&W ECOL306',
            'AN SCI/DY SCI361', 'AN SCI/DY SCI363', 'AGRONOMY/HORT338', 'GENETICS466',
            # Land Thematic Area
            'AGRONOMY300', 'AGRONOMY/DY SCI471', 'PL PATH/HORT261', 'PL PATH/HORT262',
            'SOIL SCI301', 'SOIL SCI321', 'BSE301', 'F&W ECOL/ENVIR ST371',
            'GEOG/CIV ENGR/ENVIR ST377', 'F&W ECOL395',
            # Ecosystems Thematic Area
            'HORT/AGRONOMY376', 'AGRONOMY/BOTANY/SOIL SCI370', 'PL PATH315',
            'HORT320', 'SOIL SCI/F&W ECOL451', 'SOIL SCI/GEOG526',
            'ENTOM/BOTANY/ZOOLOGY473', 'AGRONOMY/ATM OCN/SOIL SCI532',
            # People Thematic Area
            'C&E SOC/SOC340', 'AGRONOMY377', 'HORT/HIST SCI301',
            'C&E SOC/SOC533', 'PL PATH311', 'AAE/AGRONOMY/NUTR SCI350',
            'C&E SOC/SOC341', 'C&E SOC/SOC541', 'LSC340',
            'AAE/INTL ST373', 'AGRONOMY/C&E SOC/MED HIST/PHILOS565',
            'C&E SOC/SOC/URB R PL617', 'AAE422', 'C&E SOC/SOC573'
        ],
        2: [],  # No courses must be taken together within Major Breadth
        3: []   # No mutually exclusive course sequences beyond thematic areas
    },

    'h2_8': {  # Major Depth
        80: 1,  # Number of course options to choose (complete one thematic area)
        1: [
            # Organisms Thematic Area
            'ENTOM/ZOOLOGY302', 'BOTANY500', 'F&W ECOL306', 'SOIL SCI/PL PATH323',
             'ENTOM321', 'PL PATH/BOTANY332', 'F&W ECOL401', 'PL PATH/BOTANY/ENTOM505',
            # Land Thematic Area
            'AGRONOMY/BOTANY/SOIL SCI370', 'BOTANY/F&W ECOL455',
             'BOTANY/F&W ECOL/ZOOLOGY460', 'ENVIR ST/LAND ARC361',
            # Ecosystems Thematic Area
            'HORT/AGRONOMY376', 'AGRONOMY/BOTANY/SOIL SCI370', 'PL PATH315',
             'HORT320', 'SOIL SCI/F&W ECOL451', 'SOIL SCI/GEOG526',
             'ENTOM/BOTANY/ZOOLOGY473', 'AGRONOMY/ATM OCN/SOIL SCI532',
            # People Thematic Area
            'C&E SOC/SOC340', 'AGRONOMY377', 'HORT/HIST SCI301',
             'C&E SOC/SOC533', 'PL PATH311', 'AAE/AGRONOMY/NUTR SCI350',
             'C&E SOC/SOC341', 'C&E SOC/SOC541', 'LSC340',
             'AAE/INTL ST373', 'AGRONOMY/C&E SOC/MED HIST/PHILOS565',
             'C&E SOC/SOC/URB R PL617', 'AAE422', 'C&E SOC/SOC573'
        ],
        2: [],  # No courses must be taken together within Major Depth
        3: []   # No mutually exclusive course sequences beyond thematic areas
    },

    'h2_9': {  # Engineering
        80: 21,  # Number of credits to choose
        1: [
            # Placeholder list of Engineering courses (300-699)
            # Replace with actual course codes as needed
            'BME300', 'CBE305', 'CIV ENGR310', 'ECE320', 'EMA300',
            'EP300', 'GLE300', 'ISE310', 'MSE300', 'ME305',
            'NE300', 'INTEREGR300', 'MSE310', 'ME400',
            'NuclearEng305', 'OtherEngineeringCourse1', 'OtherEngineeringCourse2',
            'OtherEngineeringCourse3', 'OtherEngineeringCourse4', 'OtherEngineeringCourse5',
            'OtherEngineeringCourse6'
        ],
        2: [],  # No courses must be taken together within Engineering
        3: []   # No mutually exclusive course sequences within Engineering
    },

    'h2_10': {  # Laboratory Experience
        80: 3,  # Number of credits to choose
        1: [
            'EMA522',          # Aerodynamics Lab, 3 credits
            'PHYSICS307',      # Intermediate Laboratory-Mechanics and Modern Physics, 2 credits
            'PHYSICS321',      # Electric Circuits and Electronics, 2 credits
            'PHYSICS325',      # Optics, 2 credits
            'PHYSICS407',      # Advanced Laboratory, 2 credits
            'PHYSICS623',      # Electronic Aids to Measurement, 2 credits
            'PHYSICS625',      # Applied Optics, 2 credits
            'ECE270',          # Circuits Laboratory I, 1 credit
            'EMA/M E307'       # Mechanics of Materials Lab, 1 credit
        ],
        2: [],  # No courses must be taken together within Laboratory Experience
        3: []   # No mutually exclusive course sequences within Laboratory Experience
    },

    'h2_11': {  # Computational Experience
        80: 1,  # Number of course options to choose
        1: [
            'COMP SCI412',             # Introduction to Numerical Methods, 3 credits
            'EP/EMA471',               # Intermediate Problem Solving for Engineers, 3 credits
            'MATH/COMP SCI513',        # Numerical Linear Algebra, 3 credits
            'MATH/COMP SCI514'         # Numerical Analysis, 3 credits
        ],
        2: [],  # No courses must be taken together within Computational Experience
        3: [
            ('COMP SCI412',),
            ('EP/EMA471',),
            ('MATH/COMP SCI513',),
            ('MATH/COMP SCI514',)
        ]
    },

    'h2_12': {  # Capstone
        80: 1,  # Number of course options to choose
        1: [
            'AGROECOL503'  # Agroecology Capstone, 3 credits
        ],
        2: [
            ('AGROECOL503',)
        ],
        3: [
            ('AGROECOL503',)
        ]
    }
}

# %%
# d['applied-mathematics-engineering-program-bs'] = major_requirements

# %%
major_requirements = {
    'count': 34,  # Total credits required for the major

    'h2_1': {  # Astronomy 1
        80: 2,  # Number of course options to choose (complete at least two)
        1: [
            'ASTRON310',  # Stellar Astrophysics 2
            'ASTRON320',  # The Interstellar Medium
            'ASTRON330',  # Galaxies 2
            'ASTRON335',  # Cosmology 2
            'ASTRON340',  # Solar System Astrophysics
            'ASTRON500'   # Techniques of Modern Observational Astrophysics 2
        ],
        2: [
            # No must-take-together courses; selection based on choosing at least two
        ],
        3: [
            # No mutually exclusive sequences; students can choose any two or more
        ]
    },

    'h2_2': {  # Introductory Physics Sequences
        80: 1,  # Number of sequences to choose (complete one)
        1: [
        'PHYSICS247', 'PHYSICS248', 'PHYSICS249',  # Sequence 1
            'PHYSICS201', 'PHYSICS202', 'PHYSICS205',  # Sequence 2
            'PHYSICS207', 'PHYSICS208', 'PHYSICS241'   # Sequence 3
        ],
        2: [
            ('PHYSICS247', 'PHYSICS248', 'PHYSICS249'),  # Must take all three courses together
            ('PHYSICS201', 'PHYSICS202', 'PHYSICS205'),  # Must take all three courses together
            ('PHYSICS207', 'PHYSICS208', 'PHYSICS241')   # Must take all three courses together
        ],
        3: [
            ('PHYSICS247', 'PHYSICS248', 'PHYSICS249'),
            ('PHYSICS201', 'PHYSICS202', 'PHYSICS205'),
            ('PHYSICS207', 'PHYSICS208', 'PHYSICS241')
        ]
    },

    'h2_3': {  # Physics Core Courses
        80: 1,  # Must take all core courses
        1: [
            'PHYSICS311',  # Mechanics
            'PHYSICS322',  # Electromagnetic Fields
            'PHYSICS415'   # Thermal Physics
        ],
        2: [
            # Must take all three courses together
        ],
        3: [
            # No mutually exclusive sequences within core courses
        ]
    },

    'h2_4': {  # Atomic Quantum Physics
        80: 1,  # Number of options to choose (complete either option)
        1: [
            'PHYSICS448', 'PHYSICS449',  # Atomic and Quantum Physics (complete both)
            'PHYSICS531'                   # Introduction to Quantum Mechanics (complete one)
        ],
        2: [
            ('PHYSICS448', 'PHYSICS449')   # Must take both courses together
        ],
        3: [
            ('PHYSICS448', 'PHYSICS449'),
            ('PHYSICS531',)
        ]
    },

    'h2_5': {  # Laboratory Experience
        80: 1,  # Number of lab courses to choose (complete one)
        1: [
            'ASTRON465',  # Observational Astronomy and Data Analysis, 3 credits
            'PHYSICS307'   # Intermediate Laboratory-Mechanics and Modern Physics, 2 credits
        ],
        2: [
            # No must-take-together courses within lab experience
        ],
        3: [
            ('ASTRON465',),
            ('PHYSICS307',)
        ]
    },

    'h2_6': {  # Additional PHYSICS to Reach 28 Credits
        80: 2,  # Number of courses needed depends on previous selections
        1: [
            # List of PHYSICS courses numbered 300 and above
            'PHYSICS300', 'PHYSICS301', 'PHYSICS302', 'PHYSICS303',
            'PHYSICS304', 'PHYSICS305', 'PHYSICS306', 'PHYSICS307',
            'PHYSICS308', 'PHYSICS309', 'PHYSICS310', 'PHYSICS311',
            'PHYSICS312', 'PHYSICS313', 'PHYSICS314', 'PHYSICS315',
            'PHYSICS316', 'PHYSICS317', 'PHYSICS318', 'PHYSICS319',
            'PHYSICS320', 'PHYSICS321', 'PHYSICS322', 'PHYSICS323',
            'PHYSICS324', 'PHYSICS325', 'PHYSICS326', 'PHYSICS327',
            'PHYSICS328', 'PHYSICS329', 'PHYSICS330', 'PHYSICS331',
            'PHYSICS332', 'PHYSICS333', 'PHYSICS334', 'PHYSICS335',
            'PHYSICS336', 'PHYSICS337', 'PHYSICS338', 'PHYSICS339',
            'PHYSICS340', 'PHYSICS341', 'PHYSICS342', 'PHYSICS343',
            'PHYSICS344', 'PHYSICS345', 'PHYSICS346', 'PHYSICS347',
            'PHYSICS348', 'PHYSICS349', 'PHYSICS350', 'PHYSICS351',
            'PHYSICS352', 'PHYSICS353', 'PHYSICS354', 'PHYSICS355',
            'PHYSICS356', 'PHYSICS357', 'PHYSICS358', 'PHYSICS359',
            'PHYSICS360'
            # Add more as necessary
        ],
        2: [
            # No must-take-together courses
        ],
        3: [
            # No mutually exclusive sequences
        ]
    },

    'h2_7': {  # Total Credits
        80: 1,  # Represents the total credit requirement
        1: [
            # Not necessary to list courses here; handled via other categories
        ],
        2: [],
        3: []
    }
}

# %%
d['astronomy-physics-bs'] = major_requirements

# %%
major_requirements = {
    'count': 53,  # Total credits required for the major

    'h2_1': {  # Calculus
        80: 1,  # Number of course options to choose (complete all)
        1: [
            'MATH221',  # Calculus and Analytic Geometry 1, 5 credits
            'MATH222',  # Calculus and Analytic Geometry 2, 4 credits
            'MATH234'   # Calculus--Functions of Several Variables, 4 credits
        ],
        2: [
            ('MATH221', 'MATH222', 'MATH234')  # Must take all three courses together
        ],
        3: [
            ('MATH221', 'MATH222', 'MATH234')  # Single grouped sequence
        ]
    },

    'h2_2': {  # Physics Group 1
        80: 1,  # Number of course options to choose (complete one)
        1: [
            'PHYSICS207',  # General Physics, 5 credits
            'PHYSICS201',  # General Physics, 5 credits
            'PHYSICS247'   # A Modern Introduction to Physics, 5 credits
        ],
        2: [
            ('PHYSICS207',),
            ('PHYSICS201',),
            ('PHYSICS247',)
        ],
        3: [
            ('PHYSICS207',),
            ('PHYSICS201',),
            ('PHYSICS247',)
        ]
    },

    'h2_3': {  # Physics Group 2
        80: 1,  # Number of course options to choose (complete one)
        1: [
            'PHYSICS208',  # General Physics, 5 credits
            'PHYSICS202',  # General Physics, 5 credits
            'PHYSICS248'   # A Modern Introduction to Physics, 5 credits
        ],
        2: [
            ('PHYSICS208',),
            ('PHYSICS202',),
            ('PHYSICS248',)
        ],
        3: [
            ('PHYSICS208',),
            ('PHYSICS202',),
            ('PHYSICS248',)
        ]
    },

    'h2_4': {  # Computer Sciences
        80: 1,  # Number of course options to choose (complete one)
        1: [
            'COMP SCI220',          # Data Science Programming I, 3 credits
            'COMP SCI310',          # Problem Solving Using Computers, 3 credits
            'COMP SCI320',          # Data Science Programming II, 3 credits
            'COMP SCI/ECE354',      # Machine Organization and Programming, 3 credits
            'COMP SCI412',          # Introduction to Numerical Methods, 3 credits
            'COMP SCI/I SY E/MATH425'  # Introduction to Combinatorial Optimization, 3 credits
        ],
        2: [
            # No courses must be taken together; select any one
        ],
        3: [
            ('COMP SCI220',),
            ('COMP SCI310',),
            ('COMP SCI320',),
            ('COMP SCI/ECE354',),
            ('COMP SCI412',),
            ('COMP SCI/I SY E/MATH425',)
        ]
    },

    'h2_5': {  # Core Sequence
        80: 1,  # Number of course options to choose (complete all)
        1: [
            'ATM OCN310',  # Dynamics of the Atmosphere and Ocean I, 3 credits
            'ATM OCN311',  # Dynamics of the Atmosphere and Ocean II, 3 credits
            'ATM OCN330',  # Physics of the Atmosphere and Ocean I, 3 credits
            'ATM OCN340'   # Physics of the Atmosphere and Ocean II, 3 credits
        ],
        2: [
            ('ATM OCN310', 'ATM OCN311', 'ATM OCN330', 'ATM OCN340')  # Must take all four courses together
        ],
        3: [
            ('ATM OCN310', 'ATM OCN311', 'ATM OCN330', 'ATM OCN340')  # Single grouped sequence
        ]
    },

    'h2_6': {  # Quantitative Analysis
        80: 1,  # Number of course options to choose (complete one)
        1: [
            'COMP SCI412',  # Introduction to Numerical Methods, 3 credits
            'COMP SCI/​MATH/​STAT475',  # Introduction to Combinatorics, 3 credits
            'COMP SCI/​MATH514',  # Numerical Analysis, 3 credits
            'COMP SCI/I SY E/​MATH/​STAT525',  # Linear Optimization, 3 credits
            'MATH/​STAT309',  # Introduction to Probability and Mathematical Statistics I, 3 credits
            'MATH/​STAT310',  # Introduction to Probability and Mathematical Statistics II, 3 credits
            'MATH319',  # Techniques in Ordinary Differential Equations, 3 credits
            'MATH320',  # Linear Algebra and Differential Equations, 3 credits
            'MATH321',  # Applied Mathematical Analysis, 3 credits
            'MATH322',  # Applied Mathematical Analysis, 3 credits
            'MATH331',  # Introductory Probability, 3 credits
            'MATH340',  # Elementary Matrix and Linear Algebra, 3 credits
            'MATH341',  # Linear Algebra, 3 credits
            'MATH375',  # Topics in Multi-Variable Calculus and Linear Algebra, 3 credits
            'MATH376',  # Topics in Multi-Variable Calculus and Differential Equations, 3 credits
            'MATH407',  # Topics in Mathematics Study Abroad, 3 credits
            'MATH415',  # Applied Dynamical Systems, Chaos and Modeling, 3 credits
            'MATH421',  # The Theory of Single Variable Calculus, 3 credits
            'MATH425',  # Introduction to Combinatorial Optimization, 3 credits
            'MATH431',  # Introduction to the Theory of Probability, 3 credits
            'MATH443',  # Applied Linear Algebra, 3 credits
            'MATH461',  # College Geometry I, 3 credits
            'MATH467',  # Introduction to Number Theory, 3 credits
            'MATH471',  # Mathematics for Secondary School Teachers, 3 credits
            'MATH473',  # History of Mathematics, 3 credits
            'MATH475',  # Introduction to Combinatorics, 3 credits
            'MATH490',  # Undergraduate Seminar, 3 credits
            'MATH491',  # Topics in Undergraduate Mathematics, 3 credits
            'MATH513',  # Numerical Linear Algebra, 3 credits
            'MATH514',  # Numerical Analysis, 3 credits
            'MATH519',  # Ordinary Differential Equations, 3 credits
            'MATH521',  # Analysis I, 3 credits
            'MATH522',  # Analysis II, 3 credits
            'MATH525',  # Linear Optimization, 3 credits
            'MATH531',  # Probability Theory, 3 credits
            'MATH535',  # Mathematical Methods in Data Science, 3 credits
            'MATH540',  # Linear Algebra II, 3 credits
            'MATH541',  # Modern Algebra, 3 credits
            'MATH542',  # Modern Algebra, 3 credits
            'MATH551',  # Elementary Topology, 3 credits
            'MATH552',  # Elementary Geometric and Algebraic Topology, 3 credits
            'MATH561',  # Differential Geometry, 3 credits
            'MATH567',  # Modern Number Theory, 3 credits
            'MATH570',  # Fundamentals of Set Theory, 3 credits
            'MATH571',  # Mathematical Logic, 3 credits
            'MATH605',  # Stochastic Methods for Biology, 3 credits
            'MATH607',  # Topics in Mathematics Study Abroad, 3 credits
            'MATH609',  # Mathematical Methods for Systems Biology, 3 credits
            'MATH619',  # Analysis of Partial Differential Equations, 3 credits
            'MATH621',  # Introduction to Manifolds, 3 credits
            'MATH623',  # Complex Analysis, 3 credits
            'MATH627',  # Introduction to Fourier Analysis, 3 credits
            'MATH629',  # Introduction to Measure and Integration, 3 credits
            'MATH632',  # Introduction to Stochastic Processes, 3 credits
            'STAT309',  # Introduction to Probability and Mathematical Statistics I, 3 credits
            'STAT310',  # Introduction to Probability and Mathematical Statistics II, 3 credits
            'STAT311',  # Introduction to Theory and Methods of Mathematical Statistics I, 3 credits
            'STAT312',  # Introduction to Theory and Methods of Mathematical Statistics II, 3 credits
            'STAT324',  # Introductory Applied Statistics for Engineers, 3 credits
            'STAT333',  # Applied Regression Analysis, 3 credits
            'STAT340',  # Data Science Modeling II, 3 credits
            'STAT349',  # Introduction to Time Series, 3 credits
            'STAT351',  # Introductory Nonparametric Statistics, 3 credits
            'STAT371',  # Introductory Applied Statistics for the Life Sciences, 3 credits
            'STAT411',  # An Introduction to Sample Survey Theory and Methods, 3 credits
            'STAT421',  # Applied Categorical Data Analysis, 3 credits
            'STAT424',  # Statistical Experimental Design, 3 credits
            'STAT431',  # Introduction to the Theory of Probability, 3 credits
            'STAT456',  # Applied Multivariate Analysis, 3 credits
            'STAT461',  # Financial Statistics, 3 credits
            'STAT471',  # Introduction to Computational Statistics, 3 credits
            'STAT475',  # Introduction to Combinatorics, 3 credits
            'STAT479',  # Special Topics in Statistics, 3 credits
            'STAT525',  # Linear Optimization, 3 credits
            'STAT541',  # Introduction to Biostatistics, 3 credits
            'STAT542',  # Introduction to Clinical Trials I, 3 credits
            'STAT571',  # Statistical Methods for Bioscience I, 3 credits
            'STAT572',  # Statistical Methods for Bioscience II, 3 credits
            'STAT575',  # Statistical Methods for Spatial Data, 3 credits
            'STAT601',  # Statistical Methods I, 3 credits
            'STAT602',  # Statistical Methods II, 3 credits
            'STAT605',  # Data Science Computing Project, 3 credits
            'STAT609',  # Mathematical Statistics I, 3 credits
            'STAT610',  # Introduction to Statistical Inference, 3 credits
            'STAT615',  # Statistical Learning, 3 credits
            'STAT627',  # Professional Skills in Data Science, 3 credits
            'STAT628',  # Data Science Practicum, 3 credits
            'STAT632',  # Introduction to Stochastic Processes, 3 credits
            'STAT641',  # Statistical Methods for Clinical Trials, 3 credits
            'STAT642',  # Statistical Methods for Epidemiology, 3 credits
            'STAT679',  # Special Topics in Statistics, 3 credits
            'STAT681',  # Senior Honors Thesis, 3 credits
            'STAT682'   # Senior Honors Thesis, 3 credits
        ],
        2: [
            # No courses must be taken together; select any one
        ],
        3: [
            ('COMP SCI412',),
            ('COMP SCI/​MATH/​STAT475',),
            ('COMP SCI/​MATH514',),
            ('COMP SCI/I SY E/​MATH/​STAT525',),
            ('MATH/​STAT309',),
            ('MATH/​STAT310',),
            ('MATH319',),
            ('MATH320',),
            ('MATH321',),
            ('MATH322',),
            ('MATH331',),
            ('MATH340',),
            ('MATH341',),
            ('MATH375',),
            ('MATH376',),
            ('MATH407',),
            ('MATH415',),
            ('MATH421',),
            ('MATH425',),
            ('MATH431',),
            ('MATH443',),
            ('MATH461',),
            ('MATH467',),
            ('MATH471',),
            ('MATH473',),
            ('MATH475',),
            ('MATH490',),
            ('MATH491',),
            ('MATH513',),
            ('MATH514',),
            ('MATH519',),
            ('MATH521',),
            ('MATH522',),
            ('MATH525',),
            ('MATH531',),
            ('MATH535',),
            ('MATH540',),
            ('MATH541',),
            ('MATH542',),
            ('MATH551',),
            ('MATH552',),
            ('MATH561',),
            ('MATH567',),
            ('MATH570',),
            ('MATH571',),
            ('MATH605',),
            ('MATH607',),
            ('MATH609',),
            ('MATH619',),
            ('MATH621',),
            ('MATH623',),
            ('MATH627',),
            ('MATH629',),
            ('MATH632',),
            ('STAT309',),
            ('STAT310',),
            ('STAT311',),
            ('STAT312',),
            ('STAT324',),
            ('STAT333',),
            ('STAT340',),
            ('STAT349',),
            ('STAT351',),
            ('STAT371',),
            ('STAT411',),
            ('STAT421',),
            ('STAT424',),
            ('STAT431',),
            ('STAT456',),
            ('STAT461',),
            ('STAT471',),
            ('STAT475',),
            ('STAT479',),
            ('STAT525',),
            ('STAT541',),
            ('STAT542',),
            ('STAT571',),
            ('STAT572',),
            ('STAT575',),
            ('STAT601',),
            ('STAT602',),
            ('STAT605',),
            ('STAT609',),
            ('STAT610',),
            ('STAT615',),
            ('STAT627',),
            ('STAT628',),
            ('STAT632',),
            ('STAT641',),
            ('STAT642',),
            ('STAT679',),
            ('STAT681',),
            ('STAT682',)
        ]
    },

    'h2_7': {  # Capstone
        80: 1,  # Number of course options to choose (complete all)
        1: [
            'ATM OCN405'  # AOS Senior Capstone Seminar, 1 credit
        ],
        2: [
            ('ATM OCN405',)  # Must take this course
        ],
        3: [
            ('ATM OCN405',)
        ]
    },

    'h2_8': {  # Electives
        80: 11,  # Number of credits to choose
        1: [
            'ATM OCN401',  # Topics in Meteorology, 3 credits
            'ATM OCN404',  # Meteorological Measurements, 3 credits
            'ATM OCN425',  # Global Climate Processes, 3 credits
            'ATM OCN441',  # Radar and Satellite Meteorology, 3 credits
            'ATM OCN452',  # Synoptic Laboratory I: The Frontal Cyclone, 3 credits
            'ATM OCN453',  # Synoptic Laboratory II: Mesoscale Meteorology, 3 credits
            'ATM OCN520',  # Bioclimatology, 3 credits
            'ATM OCN522',  # Tropical Meteorology, 3 credits
            'ATM OCN532',  # Environmental Biophysics, 3 credits
            'ATM OCN535',  # Atmospheric Dispersion and Air Pollution, 3 credits
            'ATM OCN573',  # Computational Methods in Atmospheric and Oceanic Sciences, 3 credits
            'ATM OCN575',  # Climatological Analysis, 3 credits
            'ATM OCN610',  # Geophysical Fluid Dynamics I, 3 credits
            'ATM OCN611',  # Geophysical Fluid Dynamics II, 3 credits
            'ATM OCN615',  # Laboratory in Rotating Fluid Dynamics, 3 credits
            'ATM OCN630',  # Introduction to Atmospheric and Oceanic Physics, 3 credits
            'ATM OCN637',  # Cloud Physics, 3 credits
            'ATM OCN638',  # Atmospheric Chemistry, 3 credits
            'ATM OCN640',  # Radiation in the Atmosphere and Ocean, 3 credits
            'ATM OCN651',  # Synoptic-Dynamic Laboratory, 3 credits
            'ATM OCN660',  # Introduction to Physical Oceanography, 3 credits
            'ATM OCN681',  # Senior Honors Thesis, 3 credits
            'ATM OCN682',  # Senior Honors Thesis, 3 credits
            'ATM OCN691',  # Senior Thesis, 3 credits
            'ATM OCN692',  # Senior Thesis, 3 credits
            'ATM OCN698',  # Directed Study 2, 3 credits
            'ATM OCN699'   # Directed Study 2, 3 credits
        ],
        2: [
            # No specific courses must be taken together within Electives
        ],
        3: [
            # No mutually exclusive sequences within Electives
        ]
    }
}

# %%
# d['atmospheric-oceanic-sciences-bs'] = major_requirements

# %%
major_requirements = {
    'count': 53,  # Total credits required for the major

    'h2_1': {  # Mathematics Requirements
        80: 1,  # Number of course options to choose (complete one option)
        1: [
            'MATH221', 'MATH222',  # Calculus and Analytic Geometry 1 & 2, 9 credits
            'MATH171', 'MATH217', 'MATH222'  # Calculus with Algebra and Trigonometry I & II and Calculus and Analytic Geometry 2, 14 credits
        ],
        2: [
            ('MATH221', 'MATH222'),  # Must take Calculus and Analytic Geometry 1 & 2 together
            ('MATH171', 'MATH217', 'MATH222')  # Must take Calculus with Algebra and Trigonometry I & II and Calculus and Analytic Geometry 2 together
        ],
        3: [
            ('MATH221', 'MATH222'),  # Option 1: Calculus and Analytic Geometry
            ('MATH171', 'MATH217', 'MATH222')  # Option 2: Calculus with Algebra and Trigonometry
        ]
    },

    'h2_2': {  # General Chemistry Requirements
        80: 1,  # Number of course options to choose (complete one sequence)
        1: [
            'CHEM103', 'CHEM104',  # General Chemistry I & II, 9 credits
            'CHEM109',  # Advanced General Chemistry, 5 credits
            'CHEM115', 'CHEM116'  # Chemical Principles I & II (satisfies both general and analytical chemistry), 10 credits
        ],
        2: [
            ('CHEM103', 'CHEM104'),  # Must take General Chemistry I & II together
            ('CHEM109',),  # Must take Advanced General Chemistry
            ('CHEM115', 'CHEM116')  # Must take Chemical Principles I & II together
        ],
        3: [
            ('CHEM103', 'CHEM104'),  # Option 1: General Chemistry I & II
            ('CHEM109',),  # Option 2: Advanced General Chemistry
            ('CHEM115', 'CHEM116')  # Option 3: Chemical Principles I & II
        ]
    },

    'h2_3': {  # Organic Chemistry Requirements
        80: 1,  # Number of course options to choose (complete all)
        1: [
            'CHEM343',  # Organic Chemistry I, 3 credits
            'CHEM344',  # Introductory Organic Chemistry Laboratory, 2 credits
            'CHEM345'   # Organic Chemistry II, 3 credits
        ],
        2: [
            ('CHEM343', 'CHEM344', 'CHEM345')  # Must take all three Organic Chemistry courses together
        ],
        3: [
            ('CHEM343', 'CHEM344', 'CHEM345')  # Single grouped sequence
        ]
    },

    'h2_4': {  # Analytical Chemistry Requirements
        80: 1,  # Number of course options to choose (complete one)
        1: [
            'CHEM327',  # Fundamentals of Analytical Science, 4 credits
            'CHEM329',  # Fundamentals of Analytical Science, 4 credits
            'CHEM116'   # Chemical Principles II (satisfies both general and analytical chemistry), 5 credits
        ],
        2: [
            ('CHEM327',),  # Must take Fundamentals of Analytical Science I
            ('CHEM329',),  # Must take Fundamentals of Analytical Science II
            ('CHEM116',)   # Must take Chemical Principles II
        ],
        3: [
            ('CHEM327',),
            ('CHEM329',),
            ('CHEM116',)
        ]
    },

    'h2_5': {  # Physical Chemistry Requirements
        80: 1,  # Number of course options to choose (complete one)
        1: [
            'CHEM665',  # Biophysical Chemistry (Recommended), 3 credits
            'CHEM561', 'CHEM563',  # Physical Chemistry I & Physical Chemistry Laboratory I, 4 credits
            'CHEM561', 'CHEM563',  # Duplicate tuple for clarity
            'CHEM665'    # Included again for options
        ],
        2: [
            ('CHEM665',),
            ('CHEM561', 'CHEM563')
        ],
        3: [
            ('CHEM665',),
            ('CHEM561', 'CHEM563')
        ]
    },

    'h2_6': {  # Biology Requirements
        80: 2,  # Number of options to choose (Option A or Option B)
        1: [
            # Option A: Introductory and Upper-Level Biology
            {
                'option': 'Option A',
                'courses': [
                    ('BIOLOGY151', 'BIOLOGY152'),  # Introductory Biology I & II, 10 credits
                    ('ANAT&PHY335', 'ANAT&PHY337', 'ANAT&PHY435', 'AGRONOMY300', 'AGRONOMY302')  # At least 6 credits of upper-level biological science coursework
                ],
                'credits': 16
            },
            # Option B: Biocore
            {
                'option': 'Option B',
                'courses': [
                    'BIOCORE381',  # Evolution, Ecology, and Genetics, 3 credits
                    'BIOCORE383',  # Cellular Biology, 3 credits
                    'BIOCORE485',  # Principles of Physiology, 3 credits
                    'BIOCORE587',  # Biological Interactions, 3 credits
                    ('BIOCORE382', 'BIOCORE384')  # Two of the lab classes, 4 credits
                ],
                'credits': 16
            }
        ],
        2: [
            # Option A Group
            ('BIOLOGY151', 'BIOLOGY152'),
            ('ANAT&PHY335', 'ANAT&PHY337', 'ANAT&PHY435', 'AGRONOMY300', 'AGRONOMY302'),
            # Option B Group
            ('BIOCORE381', 'BIOCORE383', 'BIOCORE485', 'BIOCORE587'),
            ('BIOCORE382', 'BIOCORE384'),
            ('BIOCORE486',),  # Additional lab options if needed
            ('BIOCORE486', 'BIOCORE487')  # Example for multiple lab options
        ],
        3: [
            # Mutually exclusive options: Option A or Option B
            ('BIOLOGY151', 'BIOLOGY152', 'ANAT&PHY335', 'ANAT&PHY337', 'ANAT&PHY435', 'AGRONOMY300', 'AGRONOMY302'),
            ('BIOCORE381', 'BIOCORE383', 'BIOCORE485', 'BIOCORE587', 'BIOCORE382', 'BIOCORE384')
        ]
    },

    'h2_7': {  # Physics (Calculus-Based) Requirements
        80: 1,  # Number of course options to choose (complete one)
        1: [
            ('PHYSICS207', 'PHYSICS208'),  # General Physics I & II (recommended), 10 credits
            ('PHYSICS201', 'PHYSICS202')   # General Physics I & II, 10 credits
        ],
        2: [
            ('PHYSICS207', 'PHYSICS208'),  # Must take General Physics I & II together
            ('PHYSICS201', 'PHYSICS202')   # Must take General Physics I & II together
        ],
        3: [
            ('PHYSICS207', 'PHYSICS208'),  # Option 1: General Physics I & II (recommended)
            ('PHYSICS201', 'PHYSICS202')   # Option 2: General Physics I & II
        ]
    },

    'h2_8': {  # Biochemistry Requirements
        80: 1,  # Number of course options to choose (complete one introductory sequence and capstone)
        1: [
            # Introductory Courses
            {
                'option': 'Introductory Sequence',
                'courses': [
                    ('BIOCHEM501', 'BIOCHEM502'),  # Introduction to Biochemistry I & II, 6-7 credits
                    ('BIOCHEM507', 'BIOCHEM508')   # General Biochemistry I & II, 6-7 credits
                ],
                'credits': 6  # Adjust based on selection
            },
            # Advanced Biochemistry Electives
            {
                'option': 'Advanced Electives',
                'courses': [
                    'BIOCHEM510',  # Nutritional Biochemistry and Metabolism, 3 credits
                    'BIOCHEM560',  # Principles of Human Disease and Biotechnology, 3 credits
                    'BIOCHEM570',  # Advanced Topics in Biochemistry, 3 credits
                    'BIOCHEM575',  # Biology of Viruses, 3 credits
                    'BIOCHEM601',  # Protein and Enzyme Structure and Function, 3 credits
                    'BIOCHEM609',  # Mathematical Methods for Systems Biology, 3 credits
                    'BIOCHEM612',  # Prokaryotic Molecular Biology, 3 credits
                    'BIOCHEM620',  # Eukaryotic Molecular Biology, 3 credits
                    'BIOCHEM621',  # Plant Biochemistry, 3 credits
                    'BIOCHEM625',  # Mechanisms of Action of Vitamins and Minerals, 3 credits
                    'BIOCHEM645'   # Molecular Control of Metabolism and Metabolic Disease, 3 credits
                ],
                'credits': 3  # Must select one advanced elective
            },
            # Capstone Course
            'BIOCHEM551'  # Biochemical Methods, 4 credits
        ],
        2: [
            # Introductory Sequences
            ('BIOCHEM501', 'BIOCHEM502'),
            ('BIOCHEM507', 'BIOCHEM508'),
            # Advanced Elective
            ('BIOCHEM510',),
            ('BIOCHEM560',),
            ('BIOCHEM570',),
            ('BIOCHEM575',),
            ('BIOCHEM601',),
            ('BIOCHEM609',),
            ('BIOCHEM612',),
            ('BIOCHEM620',),
            ('BIOCHEM621',),
            ('BIOCHEM625',),
            ('BIOCHEM645',),
            # Capstone
            ('BIOCHEM551',)
        ],
        3: [
            # Introductory Sequence Options
            ('BIOCHEM501', 'BIOCHEM502'),
            ('BIOCHEM507', 'BIOCHEM508'),
            # Advanced Elective Options (choose one)
            ('BIOCHEM510',),
            ('BIOCHEM560',),
            ('BIOCHEM570',),
            ('BIOCHEM575',),
            ('BIOCHEM601',),
            ('BIOCHEM609',),
            ('BIOCHEM612',),
            ('BIOCHEM620',),
            ('BIOCHEM621',),
            ('BIOCHEM625',),
            ('BIOCHEM645',),
            # Capstone
            ('BIOCHEM551',)
        ]
    },

    'h2_9': {  # Capstone Requirements
        80: 1,  # Number of course options to choose (complete all)
        1: [
            'BIOCHEM551'  # Biochemical Methods, 4 credits
        ],
        2: [
            ('BIOCHEM551',)  # Must take this course
        ],
        3: [
            ('BIOCHEM551',)  # Single grouped sequence
        ]
    }
}

# %%
# d['biochecmistry-ba'] = major_requirements

# %%
# d['biochemistry-bs'] = major_requirements

# %%
import json

# %%
with open("bigtestdata.json", "w") as f:
    json.dump(d, f)
